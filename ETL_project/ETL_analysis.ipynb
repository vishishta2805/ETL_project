# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("supabase_url"), os.getenv("supabase_key"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             200 non-null    int64
#  1   sepal_length   200 non-null    float64
#  2   sepal_width    200 non-null    float64
#  3   petal_length   200 non-null    float64
#  4   petal_width    200 non-null    float64
#  5   species        200 non-null    object
#  6   sepal_ratio    200 non-null    float64
#  7   petal_ratio    200 non-null    float64
#  8   is_petal_long  200 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 14.2+ KB
# Index(['id', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species', 'sepal_ratio', 'petal_ratio', 'is_petal_long'],
#       dtype='object')
